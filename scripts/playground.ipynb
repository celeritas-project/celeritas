# %%
from pyzotero import zotero

with open('/Users/seth/.config/zotero-token') as f:
    API_KEY = f.read().strip()

# %%
import zoteropubs
# %load_ext autoreload
# %aimport zoteropubs

# %%
zot = zotero.Zotero(2380941, "group", API_KEY)

def sorted_collection(name):
    return zoteropubs.sorted_data_by_date(zoteropubs.collection_items_top(zot, name))

# %%
c = sorted_collection("Code objects")
# Out:
# Loading Code objects.........✔

# %%
item = c[0]
item['creators']
# Out:
# [{'creatorType': 'programmer', 'firstName': 'Seth R.', 'lastName': 'Johnson'},
#  {'creatorType': 'programmer', 'firstName': 'Amanda', 'lastName': 'Lund'},
#  {'creatorType': 'programmer', 'firstName': 'Julien', 'lastName': 'Esseiva'},
#  {'creatorType': 'programmer', 'firstName': 'Philippe', 'lastName': 'Canal'},
#  {'creatorType': 'programmer', 'firstName': 'Elliott', 'lastName': 'Biondo'},
#  {'creatorType': 'programmer',
#   'firstName': 'Hayden',
#   'lastName': 'Hollenbeck'},
#  {'creatorType': 'programmer', 'firstName': 'Stefano', 'lastName': 'Tognini'},
#  {'creatorType': 'programmer', 'firstName': 'Lance', 'lastName': 'Bullerwell'},
#  {'creatorType': 'programmer', 'firstName': 'Soon Yung', 'lastName': 'Jun'},
#  {'creatorType': 'programmer', 'firstName': 'Guilherme', 'lastName': 'Lima'},
#  {'creatorType': 'programmer', 'firstName': 'Damien', 'lastName': 'L-G'},
#  {'creatorType': 'programmer', 'firstName': 'Sakib', 'lastName': 'Rahman'},
# ...

# %%
import copy
temp_c = copy.deepcopy(c)

# %%
def set_name(d, full_name):
    names = full_name.split(' ')
    if len(names) > 1:
        d['firstName'] = ' '.join(names[:-1])
        d['lastName'] = names[-1]
        return True
    return False

def split_name(d):
    """Split a name field into firstName and lastName fields."""
    if 'name' in d:
        full_name = d['name']
        set_name(d, full_name)
        del d['name']
        return True  
    elif not d['firstName']:
        # Full name accidentally in lastName field
        full_name = d['lastName']
        set_name(d, full_name)
        return True
    elif not d['lastName']:
        print(f"No last name in {d['key']}")
    return False  # indicate no change was made

def combined_name(d):
    """Combine firstName and lastName into a single name field."""
    return " ".join([v for k in ['name', 'firstName', 'lastName'] if (v := d.get(k))])

def process_items(items):
    """Process items by splitting names in creators and contributors fields.
    Returns a list of modified items."""
    modified = []
    
    for item in items:
        item_modified = False
        
        for k in ['creators', 'contributors']:
            existing = set()
            authors = item.get(k, [])
            new_authors = []
            for d in authors:
                if split_name(d):
                    item_modified = True
                name = combined_name(d)
                if name not in existing:
                    existing.add(name)
                    new_authors.append(d)
        
            if len(authors) != len(new_authors):
                # Remove duplicates
                item_modified = True
                item[k] = new_authors
        
        # Add to modified list if any changes were made
        if item_modified:
            modified.append(item)
    
    return modified

# %%
modified = process_items(temp_c)

# %%
import datetime
now = datetime.datetime.now()
nowtime = now.strftime("%Y-%m-%dT%H:%M:%SZ")
for d in modified:
    d['dateModified'] = nowtime

# %%
modified
# Out:
# [{'key': 'CHIK34VX',
#   'version': 1839,
#   'itemType': 'computerProgram',
#   'title': 'Celeritas 0.6',
#   'creators': [{'creatorType': 'programmer',
#     'firstName': 'Seth R.',
#     'lastName': 'Johnson'},
#    {'creatorType': 'programmer', 'firstName': 'Amanda', 'lastName': 'Lund'},
#    {'creatorType': 'programmer', 'firstName': 'Julien', 'lastName': 'Esseiva'},
#    {'creatorType': 'programmer', 'firstName': 'Philippe', 'lastName': 'Canal'},
#    {'creatorType': 'programmer', 'firstName': 'Elliott', 'lastName': 'Biondo'},
#    {'creatorType': 'programmer',
#     'firstName': 'Hayden',
#     'lastName': 'Hollenbeck'},
#    {'creatorType': 'programmer',
#     'firstName': 'Stefano',
#     'lastName': 'Tognini'},
#    {'creatorType': 'programmer',
#     'firstName': 'Lance',
#     'lastName': 'Bullerwell'},
#    {'creatorType': 'programmer', 'firstName': 'Soon Yung', 'lastName': 'Jun'},
#    {'creatorType': 'programmer', 'firstName': 'Guilherme', 'lastName': 'Lima'},
# ...

# %%
zot.update_items(modified)
# Out:
# True

# %%
[d['title'] for d in modified]
# Out:
# ['Celeritas 0.6',
#  'G4VG 1.0',
#  'Celeritas 0.5',
#  'Celeritas 0.4',
#  'Celeritas 0.3',
#  'Celeritas 0.2',
#  'Celeritas 0.1']
